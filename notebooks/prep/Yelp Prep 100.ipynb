# %%
import os
import sys
import pandas as pd
import numpy as np
module_path = os.path.abspath(os.path.join('../../data/..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %matplotlib inline

# %%
#Full Check in data, separate hours
df = pd.read_csv("../../data/raw/yelp_checkin.csv") 

#group into businesses and add to make total number of checkins for each business
check = df.groupby("business_id")['checkins'].sum().sort_values(ascending=False)

# %%
checkins = pd.DataFrame(check) #read in csv file

checkins.reset_index(level = 0, inplace = True)
checkins
# Out:
#                    business_id  checkins
# 0       FaHADZARwnY4yvlvpnsfGA    131958
# 1       JmI9nslLD7KZqRr__Bg6NQ    112590
# 2       yQab5dxZzgBLTEHCw9V7_w     49934
# 3       5LNZ67Yw9RD6nf4_UhXOjw     43995
# 4       SMPbvZLSMMb7KU76YNYMGg     32603
# 5       IZivKqtHyz4-ts8KsnvMrA     32393
# 6       Wxxvi3LZbHNIDwJ-ZimtnA     30583
# 7       na4Th5DrNauOv-c43QQFvA     29271
# 8       El4FC8jcawUVgw_0EIcbaQ     28272
# 9       VyjyHoBg3KC5BSFRlD0ZPQ     27306
# 10      RESDUcs7fIiihp38-d6_6g     26378
# 11      DkYS3arLOhA8si5uUEmHOw     25158
# 12      BLIJ-p5wYuAhw6Pp6mh6mw     24664
# 13      eAc9Vd6loOgRQolMXQt6FA     24265
# 14      gy-HBIeJGlQHs4RRYDLuHw     21523
# 15      t-o_Sraneime4DDhWrQRBA     21160
# 16      K7lWdNUhCbcnEvI0NhGewg     20990
# 17      uGupeWqih0yIcCg8anM1PA     20981
# 18      4JNXUYY8wbaaDmk3BPzlWw     19138
# 19      YBLVD61RFdP5H-RGLSIPUw     18899
# 20      RhEvP5flF6KoPriMHmVYGg     18792
# 21      ii8sAGBexBOJoYRFafF9XQ     17777
# 22      IB8zLlGraOg9LU7qQVLPyg     17656
# 23      -kG0N8sBhBotMbu0KVSPaw     17070
# 24      qjnJFZtsY_nfRzoL3J_UWQ     16711
# 25      iCQpiavjjPzJ5_3gPD5Ebg     16566
# 26      yfxDa8RFOvJPQh0rNtakHA     16322
# 27      GHS1rVjO-RMcRB6WJLpCDQ     16026
# 28      hihud--QRriCYZw1zZvW4g     15797
# 29      p0iEUamJVp_QpaheE-Nz_g     15754
# ...                        ...       ...
# 146320  3pN4Zqfah-EEjQY1B-8Tcg         1
# 146321  yytp6Ii6o8Zo-C4Iag-9fw         1
# 146322  9gHivsv7yFSh8Qas7E-AJg         1
# 146323  9gC44DSWlq2Zg0QzLGx4og         1
# 146324  PIWIbVEkc_XkjD2ZOuppcg         1
# 146325  d2k0I5mbDiOYrCAjJLLMiQ         1
# 146326  3qHNkj30x-KE1FunI4koUQ         1
# 146327  3q9m2KpNP3-QpbJt84UHOg         1
# 146328  d2k5Rw2S9UprfwaTuaNFRA         1
# 146329  PHlk6jVvpQfMFWOV2Z1CAw         1
# 146330  PHb9AgEVXzuV4ETl3w5onQ         1
# 146331  3q-wz3uGYy_ro_g8ZAL-BA         1
# 146332  9faFGW_3fS7oLrWk3N4aYg         1
# 146333  d3MXCu4W6T9Kv9uIQJp0oA         1
# 146334  yypxgWicbQIFw28UJnkkOA         1
# 146335  PHJpAJUUzNOpKgsJgjzuww         1
# 146336  d3ldypgDKM9voImL4Sd1qQ         1
# 146337  3pnvI_eEHzEWQJmXdcJ3rw         1
# 146338  PH-04x1c9yCvJeK2CUuzaw         1
# 146339  3pjew89aPOFNr01XNvXqhA         1
# 146340  9g0De_wpEG77RznRSgDavg         1
# 146341  9g138EC5N5XcC10TV_9OWQ         1
# 146342  d3t2d2XeZiuqvj8Cwhe4dg         1
# 146343  d42bTf4-EmmiwWgAZwdZFA         1
# 146344  d43KBUWXsGvwuAbC6QA2Cw         1
# 146345  PGRMh2cpYdl1wFF8RsAxZg         1
# 146346  PFtJ_YixaNgajPyxHeUpsQ         1
# 146347  PFnZzICyeAUhoIDazsVgGQ         1
# 146348  d4TOkUhfqScHfcEO8wPmZQ         1
# 146349  AVY5A1exjcxZKDzQVuFcug         1
#
# [146350 rows x 2 columns]

# %%
biz = pd.read_csv("../../data/raw/yelp_business.csv") #read in FULL business file
biz = biz.filter(['business_id','name','city' 'stars', 'review_count', 'is_open', 'postal_code',\
                     'categories']) #filter relevant columns

# %%
#merges tables together, 'NaN' where there was no match for business_id.
bizWithCheckins = biz.merge(checkins,on='business_id', how = 'outer')
#We replace NaN with 0, because we know that NaN arises because businesses with 0 checkins do not appear in the checkin.csv
bizWithCheckins['checkins'] = bizWithCheckins['checkins'].fillna(value = 0)

# %%
bizWithCheckins.head(10)
# Out:
#               business_id                        name  review_count  is_open  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"            22        1
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"            11        1
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"            18        1
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"             9        0
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"           116        1
# 5  o9eMRCWt5PkpLDE0gOPtcQ                   "Messina"             5        1
# 6  kCoE3jvEtg6UVz5SOD3GVw                "BDJ Realty"             5        1
# 7  OD2hnuuTJI9uotcKycxg1A               "Soccer Zone"             9        1
# 8  EsMcGiZaQuG1OOvL9iUFug          "Any Given Sundae"            15        1
# 9  TGWhGNusxyMaA4kQVBNeew     "Detailing Gone Mobile"             7        1
#
#   postal_code                                         categories  checkins
# 0       85044  Dentists;General Dentistry;Health & Medical;Or...      39.0
# 1       15317  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...      15.0
# 2       85017  Departments of Motor Vehicles;Public Services ...       6.0
# 3       85282                            Sporting Goods;Shopping     120.0
# 4       44221  American (New);Nightlife;Bars;Sandwiches;Ameri...     263.0
# 5       70567                                Italian;Restaurants       1.0
# 6       89128  Real Estate Services;Real Estate;Home Services...       0.0
# 7       89128                            Shopping;Sporting Goods      27.0
# 8       15090        Coffee & Tea;Ice Cream & Frozen Yogurt;Food      15.0
# 9       89014                          Automotive;Auto Detailing       1.0

# %% [markdown]
#  ### Adding tip count totals
#  - Read in CSV file
#  - Read in filtered business file (only useful info)
#  - Find the businesses that have no tips
#  - Set their tip total to 0
#  - Combine the business info and tip totals to one dataframe

# %%
tips = pd.read_csv("../../data/raw/yelp_tip.csv")

# %%
tipCountGroup = tips.groupby("business_id").size().sort_values(ascending=False)
tipCountDf = pd.DataFrame(tipCountGroup)
tipCountDf.head()
# Out:
#                            0
# business_id
# FaHADZARwnY4yvlvpnsfGA  3517
# JmI9nslLD7KZqRr__Bg6NQ  2382
# DkYS3arLOhA8si5uUEmHOw  1474
# 5LNZ67Yw9RD6nf4_UhXOjw  1436
# K7lWdNUhCbcnEvI0NhGewg  1346

# %%
tipCountDf.reset_index(level = 0, drop = False, inplace = True)
tipCountDf.columns = ['business_id', 'tipcount']
tipCountDf.head()
# Out:
#               business_id  tipcount
# 0  FaHADZARwnY4yvlvpnsfGA      3517
# 1  JmI9nslLD7KZqRr__Bg6NQ      2382
# 2  DkYS3arLOhA8si5uUEmHOw      1474
# 3  5LNZ67Yw9RD6nf4_UhXOjw      1436
# 4  K7lWdNUhCbcnEvI0NhGewg      1346

# %%
bizComplete = bizWithCheckins.merge(tipCountDf, on = 'business_id', how = 'outer')
bizComplete['tipcount'] = bizComplete['tipcount'].fillna(0)
bizComplete.head()
# Out:
#               business_id                        name  review_count  is_open  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"            22        1
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"            11        1
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"            18        1
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"             9        0
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"           116        1
#
#   postal_code                                         categories  checkins  \
# 0       85044  Dentists;General Dentistry;Health & Medical;Or...      39.0
# 1       15317  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...      15.0
# 2       85017  Departments of Motor Vehicles;Public Services ...       6.0
# 3       85282                            Sporting Goods;Shopping     120.0
# 4       44221  American (New);Nightlife;Bars;Sandwiches;Ameri...     263.0
#
#    tipcount
# 0       5.0
# 1       1.0
# 2       0.0
# 3       3.0
# 4      17.0

# %% [markdown]
# # Postal Code Processing

# %%
ZIPmask = bizComplete['postal_code'].notnull()
bizComplete[ZIPmask].count()
# Out:
# business_id     174567
# name            174567
# review_count    174567
# is_open         174567
# postal_code     174567
# categories      174567
# checkins        174567
# tipcount        174567
# dtype: int64

# %% [markdown]
# Function to clean zip codes like Canadian ones. If a postal code is made up of 2 separated strings, the first string is returned.

# %%
def cleanZip(string):
    if string is None:
        return None
    stringList = string.split(" ")
    return stringList[0]

# %%
#received float errors for 'string.split("") in the cleanZip function.
bizComplete['postal_code'] = bizComplete['postal_code'].astype('str')

# %%
bizComplete['postal_code'] = bizComplete['postal_code'].apply(cleanZip)
bizComplete.head(10)
# Out:
#               business_id                        name  review_count  is_open  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"            22        1
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"            11        1
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"            18        1
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"             9        0
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"           116        1
# 5  o9eMRCWt5PkpLDE0gOPtcQ                   "Messina"             5        1
# 6  kCoE3jvEtg6UVz5SOD3GVw                "BDJ Realty"             5        1
# 7  OD2hnuuTJI9uotcKycxg1A               "Soccer Zone"             9        1
# 8  EsMcGiZaQuG1OOvL9iUFug          "Any Given Sundae"            15        1
# 9  TGWhGNusxyMaA4kQVBNeew     "Detailing Gone Mobile"             7        1
#
#   postal_code                                         categories  checkins  \
# 0       85044  Dentists;General Dentistry;Health & Medical;Or...      39.0
# 1       15317  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...      15.0
# 2       85017  Departments of Motor Vehicles;Public Services ...       6.0
# 3       85282                            Sporting Goods;Shopping     120.0
# 4       44221  American (New);Nightlife;Bars;Sandwiches;Ameri...     263.0
# 5       70567                                Italian;Restaurants       1.0
# 6       89128  Real Estate Services;Real Estate;Home Services...       0.0
# 7       89128                            Shopping;Sporting Goods      27.0
# 8       15090        Coffee & Tea;Ice Cream & Frozen Yogurt;Food      15.0
# 9       89014                          Automotive;Auto Detailing       1.0
#
#    tipcount
# 0       5.0
# 1       1.0
# 2       0.0
# 3       3.0
# 4      17.0
# 5       1.0
# 6       0.0
# 7       3.0
# 8       1.0
# 9       0.0
